# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\asritha\\DataScience Files'

# %%
data=pd.read_csv('creditcard_2023.csv')
data
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 0            0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898
# 1            1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605
# 2            2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481
# 3            3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312
# 4            4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549
# ...        ...       ...       ...       ...       ...       ...       ...
# 568625  568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626  568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627  568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628  568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629  568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
# ...

# %% [markdown]
# # Preprocessing

# %%
data.isnull().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#len() calculates the length of an object.
#len(data.isnull().sum())

# %%
data.isnull().any()
# Out:
# id        False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
data.shape
# Out:
# (568630, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
import matplotlib.pyplot as plt
class_counts = data["Class"].value_counts()
plt.figure(figsize=(6, 4))
plt.bar(class_counts.index, class_counts.values) 
plt.ylabel("Frequency")
plt.title("Distribution of Class in the dataset using Bar Chart")
plt.grid(axis="y")
plt.show()

# %%
import seaborn as sns
class_counts = data["Class"].value_counts()
sns.kdeplot(data["Class"], shade=True)  # Shade the density area
plt.xlabel("Class")
plt.ylabel("Density")
plt.xticks(class_counts.index)
plt.title("Distribution of Class in the dataset using KDE")
plt.xlim(-0.1, 1.1)  # Set x-axis limits to include both 0 and 1
plt.grid(axis="y")
plt.show()#

# %% [markdown]
# # Correlation

# %%
# Select numerical features
numerical_features = ["V1","V5","V10","V15","V20","V25"]
# Correlation matrix
correlation = data[numerical_features].corr()

# Print the correlation matrix
print(correlation)
# Out:
#            V1        V5       V10       V15       V20       V25
# V1   1.000000  0.517462  0.599108  0.046002 -0.219164 -0.008508
# V5   0.517462  1.000000  0.563874  0.058686 -0.246694 -0.047845
# V10  0.599108  0.563874  1.000000  0.111051 -0.287051 -0.014045
# V15  0.046002  0.058686  0.111051  1.000000 -0.135423 -0.027579
# V20 -0.219164 -0.246694 -0.287051 -0.135423  1.000000  0.030478
# V25 -0.008508 -0.047845 -0.014045 -0.027579  0.030478  1.000000

# %%
plt.figure(figsize=(13,7))
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.xlabel("Features")
plt.ylabel("Features")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # KNN ALGORITHM

# %%
#sklearn (scikitlearn)is machine learning algorithm built upon scipy.
# !pip install sklearn

# %%
# !pip show sklearn

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
## Separating the target variable
X = data.drop('Class', axis=1)
y = data['Class']
display(X)
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 0            0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898
# 1            1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605
# 2            2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481
# 3            3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312
# 4            4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549
# ...        ...       ...       ...       ...       ...       ...       ...
# 568625  568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626  568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627  568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628  568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629  568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
# ...

# %%
# Splitting the dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=100)

# %%
# Initialize the KNN model
knn = KNeighborsClassifier(n_neighbors=5)

# Train the model
knn.fit(X_train, y_train)

# Predict the labels for the test set
y_predk = knn.predict(X_test)
y_pred_traink=knn.predict(X_train)

# %%
print("Model Results for KNN Algorithm")
print("Train Accuracy:", accuracy_score(y_train, y_pred_train)*100)
print("Test Accuracy:", accuracy_score(y_test, y_predk)*100)

# %%
print(confusion_matrix(y_test, y_pred))
print("______________________________________________________________")
print("Classification report for KNN model\n")
print(classification_report(y_test, y_predk))
# Out:
# [[84983     8]
#  [   33 85565]]
# ______________________________________________________________
# Classification report for KNN model
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84991
#            1       1.00      1.00      1.00     85598
#
#     accuracy                           1.00    170589
#    macro avg       1.00      1.00      1.00    170589
# weighted avg       1.00      1.00      1.00    170589

# %% [markdown]
# # Applying Decision tree

# %%
#Importing the libraries
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score,f1_score
from sklearn import tree

# %%
X_train
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 497449  497449  0.939961 -0.082757 -0.012076  0.142502  0.598038 -0.133042
# 159918  159918  0.211574 -0.137246  0.460770 -0.818695  0.582140  0.119758
# 38829    38829 -0.134627 -0.150272  1.464025 -0.885132  0.302048 -0.085389
# 401367  401367 -1.240556  0.431864 -0.897648  1.327176 -0.989171  0.204655
# 188567  188567 -0.306533 -0.298250  0.031307 -0.579424  0.739261  0.933947
# ...        ...       ...       ...       ...       ...       ...       ...
# 344414  344414 -1.032757  0.303765 -0.826618  0.789613 -0.760521  0.069188
# 212912  212912 -0.073343 -0.300284  1.057407 -1.530589 -0.035234  0.942246
# 65615    65615 -0.558294 -1.232071  0.780267 -1.306334  0.758797 -0.161259
# 210755  210755  0.049760 -0.145740  0.605898 -0.455705  0.516175 -0.008260
# 56088    56088  0.565593 -0.774590  1.260605  0.066565 -0.150424  0.723548
#
# ...

# %%
X_test
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 309550  309550  0.191155 -0.483224  0.781430 -0.256541  0.553245  0.902720
# 418331  418331 -0.825195 -0.440651 -0.692251  1.389292  3.540342 -2.372951
# 313225  313225 -0.356774  0.289630 -0.680272  1.230539  1.737736 -1.362536
# 354977  354977 -0.327279  0.633647 -0.958833  1.410966 -0.245177 -0.645411
# 43690    43690  0.139730 -1.618817  0.114138 -1.118217 -0.150376  0.351437
# ...        ...       ...       ...       ...       ...       ...       ...
# 254532  254532 -0.193256  0.047733  0.275516 -1.180248  0.347562  0.132795
# 195556  195556  1.442479 -1.293801 -0.015067 -1.282919 -0.196192 -0.203122
# 525854  525854  0.486332 -0.005089 -0.587541  0.482773 -0.054638  0.227963
# 522556  522556 -0.061120  0.194518 -0.474255  0.709378  0.300052  0.401251
# 133970  133970  0.085071 -0.169602  1.424826 -0.396381  0.408076  0.528355
#
# ...

# %%
y_train
# Out:
# 497449    1
# 159918    0
# 38829     0
# 401367    1
# 188567    0
#          ..
# 344414    1
# 212912    0
# 65615     0
# 210755    0
# 56088     0
# Name: Class, Length: 398041, dtype: int64

# %%
y_test
# Out:
# 309550    1
# 418331    1
# 313225    1
# 354977    1
# 43690     0
#          ..
# 254532    0
# 195556    0
# 525854    1
# 522556    1
# 133970    0
# Name: Class, Length: 170589, dtype: int64

# %%
# Creating the classifier object
clf_gini = DecisionTreeClassifier(criterion="gini",random_state=100, max_depth=3, min_samples_leaf=2,min_samples_split=2,splitter="random")
# Performing training
clf_gini.fit(X_train, y_train)
print("Predicted values:")
clf_gini
# Out:
# Predicted values:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=2, random_state=100,
#                        splitter='random')

# %%
# Function to make predictions
y_pred_train = clf_gini.predict(X_train)
y_pred_train

y_pred_test = clf_gini.predict(X_test)
print("Test Predicted values:")
print(y_pred_test)
# Out:
# Test Predicted values:
# [1 1 1 ... 1 1 0]

# %%
# Plot the decision tree as a dendrogram
plt.figure(figsize=(15, 9))
plot_tree(clf_gini, filled=True, feature_names=X.columns, class_names=["0", "1"], rounded=True, fontsize=10)
plt.show()

# %%
#Checking the Accuracy of the model
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print("Model Results of Decison Tree")

print("Test Accuracy::",accuracy_score(y_test,y_pred_test)*100)
print("Train Accuracy::",accuracy_score(y_train,y_pred_train)*100)
# Out:
# Model Results of Decison Tree
# Test Accuracy:: 98.35452461764827
# Train Accuracy:: 98.37077085023904

# %%
from sklearn.metrics import confusion_matrix,classification_report
print("Confusion Matrix for decision Tree\n")
print(confusion_matrix(y_test, y_pred))
print("____________________________________________________________")
print("Classification_report for decision Tree\n")
print(classification_report(y_test, y_pred))
print("Test Accuracy::",accuracy_score(y_test,y_pred_test)*100)
# Out:
# Confusion Matrix for decision Tree
#
# [[84981    10]
#  [  155 85443]]
# ____________________________________________________________
# Classification_report for decision Tree
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84991
#            1       1.00      1.00      1.00     85598
#
#     accuracy                           1.00    170589
#    macro avg       1.00      1.00      1.00    170589
# weighted avg       1.00      1.00      1.00    170589
#
# Test Accuracy:: 98.35452461764827

# %%
#If test size=0.3, random state=100 -->Accuracy=99.96541394814436
#If test size=0.1, random state=100 -->Accuracy=99.96131051826319
#If test size=0.3, random state=50 -->Accuracy=99.96131051826319
#If test size=0.1, random state=50 -->Accuracy=99.95251745423211

# %% [markdown]
# # RANDOM FOREST

# %%
#Random Forest
import matplotlib.pyplot as plt
import sklearn

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)
print("Test Predicted values",y_pred)
y_pred_train=rfc.predict(X_train)
#print("Train Pedicted values",y_pred_train)
#y_pred_train
# Out:
# Test Predicted values [1 1 1 ... 1 1 0]

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
accuracy = accuracy_score(y_test, y_pred)*100
print("Model Results of Random Forest")
print("Train Accuracy::", accuracy_score(y_train,y_pred_train)*100)
print("Test Accuracy::",accuracy_score(y_test,y_pred)*100)
# Out:
# Model Results of Random Forest
# Train Accuracy:: 100.0
# Test Accuracy:: 99.97596562498168

# %%
print("Confusion matrix:",confusion_matrix(y_test,y_pred))
print("__________________________________________________")
print("Classification report for Random Forest\n")
print(classification_report(y_test,y_pred))
# Out:
# Confusion matrix: [[84983     8]
#  [   33 85565]]
# __________________________________________________
# Classification report for Random Forest
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84991
#            1       1.00      1.00      1.00     85598
#
#     accuracy                           1.00    170589
#    macro avg       1.00      1.00      1.00    170589
# weighted avg       1.00      1.00      1.00    170589

# %% [markdown]
# # CATBOOST ALGORITHM

# %%
#CatBoost Algorithm
from catboost import CatBoostClassifier
model = CatBoostClassifier(iterations=100, learning_rate=0.1, depth=6)

model.fit(X_train, y_train, verbose=0)

# %%
y_test_predc = model.predict(X_test)
print("Predicted values")
print(y_test_predc)
y_train_predc=model.predict(X_train)
#print(y_train_predc)
# Out:
# Predicted values
# [1 1 1 ... 1 1 0]

# %%
print("Model Results for CATBOOST ALGORITHM")
print("Train Accuracy::", accuracy_score(y_train,y_train_predc)*100)
print("Test Accuracy::",accuracy_score(y_test,y_test_predc)*100)
# Out:
# Model Results for CATBOOST ALGORITHM
# Train Accuracy:: 99.96583266547918
# Test Accuracy:: 99.95662088411328

# %%
print(confusion_matrix(y_test,y_test_predc))
print("_______________________________________________")
print("Classification_report for CatBoost Algorithm\n")
print(classification_report(y_test,y_test_predc))
# Out:
# [[84971    20]
#  [   54 85544]]
# _______________________________________________
# Classification_report for CatBoost Algorithm
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84991
#            1       1.00      1.00      1.00     85598
#
#     accuracy                           1.00    170589
#    macro avg       1.00      1.00      1.00    170589
# weighted avg       1.00      1.00      1.00    170589

# %%
# # Analyze the results
# if y_train_predc > 0.90 and (y_train_predc - y_test_predc) > 0.10:
#     print("The model is likely overfitting.")
# elif y_train_predc < 0.60 and y_test_predc < 0.60:
#     print("The model is likely underfitting.")
# else:
#     print("The model is performing well.")

# %%
from sklearn.metrics import precision_recall_fscore_support
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(4, 3))

conf_mat = confusion_matrix(y_test_predc, model.predict(X_test))

annot_labels = [f"{label}\n{count}" for label, count in zip(['TN', 'FP', 'FN', 'TP'], conf_mat.flatten())]

sns.heatmap(conf_mat, annot=np.array(annot_labels).reshape(2, 2), fmt='', cmap='Blues', annot_kws={'size': 12}, ax=ax)

result = precision_recall_fscore_support(y_test, model.predict(X_test))
print(f"Precision: {result[0][1]:.4}")
print(f"Recall: {result[1][1]:.4}")
print(f"F1-Score: {result[2][1]:.4}")

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Precision: 0.9998
# Recall: 0.9994
# F1-Score: 0.9996
